# %%
# %pip install -q xmltodict
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark

MAX_MEMORY = "8g"  # 24 gives OOM here.

spark = (pyspark.sql.SparkSession.builder.appName("MyApp") 
    .config("spark.jars.packages", "io.delta:delta-core_2.12:0.8.0") 
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") 
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") 
    .config("spark.executor.memory", MAX_MEMORY) 
    .config("spark.driver.memory", MAX_MEMORY) 
    .enableHiveSupport() 
    .getOrCreate()        
    )
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://08daf71ed0cf:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>MyApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import xmltodict
import json
def xml_to_json(x):
    try:
        return json.dumps(xmltodict.parse(x))
    except:
        return None
spark.udf.register("xml_to_json",xml_to_json)
# Out:
# <function __main__.xml_to_json(x)>

# %%
import requests
xml = requests.get('https://www.w3schools.com/xml/plant_catalog.xml').text
df_with_xml = spark.createDataFrame([[xml]],'xml string')

# %%
df_with_json = df_with_xml.selectExpr('*','xml_to_json(xml) as json')
df_with_json.show()
# Out:
# +--------------------+--------------------+
# |                 xml|                json|
# +--------------------+--------------------+
# |<?xml version="1....|{"CATALOG": {"PLA...|
# +--------------------+--------------------+

# %%
json_schema = spark.read.json(df_with_json.rdd.map(lambda row: row.json)).schema
print(json_schema)
# Out:
# StructType(List(StructField(CATALOG,StructType(List(StructField(PLANT,ArrayType(StructType(List(StructField(AVAILABILITY,StringType,true),StructField(BOTANICAL,StringType,true),StructField(COMMON,StringType,true),StructField(LIGHT,StringType,true),StructField(PRICE,StringType,true),StructField(ZONE,StringType,true))),true),true))),true)))

# %%
json_schema.simpleString()
# Out:
# 'struct<CATALOG:struct<PLANT:array<struct<AVAILABILITY:string,BOTANICAL:string,COMMON:string,LIGHT:string,PRICE:string,ZONE:string>>>>'

# %%
import pyspark.sql.functions as psf
df_with_structured_data = df_with_json.withColumn('structured_data', psf.from_json(psf.col('json'),json_schema))

# %%
df_with_structured_data.createOrReplaceTempView('view_with_structured_data')

# %%
final_clean_df = spark.sql('''
  select plant.* 
  from view_with_structured_data
  lateral view explode(structured_data.catalog.plant) as plant
''')

# %%
final_clean_df.toPandas()
# Out:
#    AVAILABILITY                 BOTANICAL               COMMON         LIGHT  \
# 0        031599    Sanguinaria canadensis            Bloodroot  Mostly Shady
# 1        030699      Aquilegia canadensis            Columbine  Mostly Shady
# 2        051799          Caltha palustris       Marsh Marigold  Mostly Sunny
# 3        030699          Caltha palustris              Cowslip  Mostly Shady
# 4        012099       Dicentra cucullaria  Dutchman's-Breeches  Mostly Shady
# 5        041899          Asarum canadense         Ginger, Wild  Mostly Shady
# 6        012699        Hepatica americana             Hepatica  Mostly Shady
# 7        010299        Hepatica americana            Liverleaf  Mostly Shady
# 8        020199       Arisaema triphyllum   Jack-In-The-Pulpit  Mostly Shady
# 9        060599      Podophyllum peltatum             Mayapple  Mostly Shady
# 10       012299          Phlox divaricata      Phlox, Woodland  Sun or Shade
# 11       021699          Phlox divaricata          Phlox, Blue  Sun or Shade
# 12       020199       Claytonia Virginica        Spring-Beauty  Mostly Shady
# 13       042999     Trillium grandiflorum             Trillium  Sun or Shade
# 14       022199     Trillium grandiflorum           Wake Robin  Sun or Shade
# 15       020199    Erythronium americanum    Violet, Dog-Tooth         Shade
# 16       032499    Erythronium americanum           Trout Lily         Shade
# 17       041399    Erythronium americanum       Adder's-Tongue         Shade
# 18       122698            Anemone blanda              Anemone  Mostly Shady
# 19       071099            Anemone blanda   Grecian Windflower  Mostly Shady
# 20       050399            Monarda didyma             Bee Balm         Shade
# 21       042799            Monarda didyma             Bergamot         Shade
# 22       061899           Rudbeckia hirta     Black-Eyed Susan         Sunny
# 23       061099                Ranunculus            Buttercup         Shade
# 24       040399                Ranunculus             Crowfoot         Shade
# 25       063099        Asclepias tuberosa       Butterfly Weed         Sunny
# 26       052599                Potentilla           Cinquefoil         Shade
# 27       013099                 Oenothera             Primrose         Sunny
# 28       051899                  Gentiana              Gentian  Sun or Shade
# 29       050299                  Gentiana         Blue Gentian  Sun or Shade
# 30       022199      Polemonium caeruleum       Jacob's Ladder         Shade
# 31       071499      Polemonium caeruleum       Greek Valerian         Shade
# 32       032799  Eschscholzia californica     California Poppy           Sun
# 33       051399               Dodecatheon        Shooting Star  Mostly Shady
# 34       071199                Cimicifuga            Snakeroot         Shade
# 35       022299        Lobelia cardinalis      Cardinal Flower         Shade
#
#     PRICE    ZONE
# 0   $2.44       4
# 1   $9.37       3
# 2   $6.81       4
# 3   $9.90       4
# 4   $6.44       3
# 5   $9.03       3
# 6   $4.45       4
# 7   $3.99       4
# 8   $3.23       4
# 9   $2.98       3
# 10  $2.80       3
# 11  $5.59       3
# 12  $6.59       7
# 13  $3.90       5
# 14  $3.20       5
# 15  $9.04       4
# 16  $6.94       4
# 17  $9.58       4
# 18  $8.86       6
# 19  $9.16       6
# 20  $4.59       4
# 21  $7.16       4
# 22  $9.80  Annual
# 23  $2.57       4
# 24  $9.34       4
# 25  $2.78  Annual
# 26  $7.06  Annual
# 27  $6.56   3 - 5
# 28  $7.81       4
# 29  $8.56       4
# 30  $9.26  Annual
# 31  $4.36  Annual
# 32  $7.89  Annual
# 33  $8.60  Annual
# 34  $5.63  Annual
# 35  $3.02       2
